# %%
from vizdoom import *
import random 
import time
import numpy as np

# Open AI Gym dependencies
import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import Discrete, Box # for random actions and nxm for random observation space (frames)
import cv2

# Stable Baselines3 dependencies
import os
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3 import PPO # training algorithm
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# Logging folders
CHECKPOINT_DIR = './TC_train/train_basic'
LOG_DIR = './TC_logs/log_basic'

# %% [markdown]
# # Deafult Actions and Reward
# ### Defining Gymnasium Wrapper for TakeCover Gameplay

# %%
# Creating Vizdoom OpenAI Gym Environment
class VizDoomGym(Env):
    def __init__(self, render_mode = False): # By default, rendering is disabled
        # Inheriting from the Env class
        super().__init__()
        # Setup game
        self.game = DoomGame()
        self.game.load_config("github_vizdoom_repo/ViZDoom/scenarios/take_cover.cfg") # Take Cover configuration file

        # Rendering mode : if unabled, the game will not be displayed but the training will be faster
        if render_mode == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)

        # Start the game
        self.game.init()
        
        # In order to get the game frame size, run a dummy demo and get the screen buffer shape  with game.get_state().screen_buffer.shape
        self.observation_space = Box(low=0, high=255, shape=(100, 160, 1), dtype = np.uint8)
        # Action space
        self.action_space = Discrete(2) # left, right
        self.current_step = 0


    # Defining how to make a step in the env
    def step(self, action):
        actions = np.identity(2, dtype=np.uint8) # Possible actions [left, right]
        reward = self.game.make_action(actions[action], 4) # Defyining the frame skip parameter to 4

        # Check if the frames are over
        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            obs = self.grayscale(state)
            health = self.game.get_state().game_variables[0]
            terminated = self.game.is_episode_finished()
            truncated = self.current_step >= 2100  # Max steps
            info = {"health": health}
        else: # Default zeros observation
            obs = np.zeros(self.observation_space.shape, dtype=np.uint8)
            terminated = True
            truncated = False
            info = {} # Empty info: no 0 beacuse the API doesn't allow it

        self.current_step += 1
        return obs, reward, terminated, truncated, info # Changed parameters order according to Gymnasium API
    
    def render():
        pass
    
    # What appens when starting a new episode
    def reset(self, seed = None, options = None):
        super().reset(seed=seed)
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)

        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        obs = self.grayscale(state)
        info = {"health": self.game.get_state().game_variables[0]}
        self.current_step = 0

        return obs, info

    # Grayscale and resize the frames in order to reduce the observation space
    ## POSSIBLE IMPROVEMENT : CUT OFF BOTTOM PART OF THE IMAGE WHERE THERE IS NO USEFUL INFORMATION
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY) # moveaxis moves the first element (0) to last position (-1)
        resize = cv2.resize(gray, (160, 100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160, 1))
        return state

    def close(self):
        self.game.close()

# %%
# Basic log and train callback
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}.zip'.format(self.n_calls))
            self.model.save(model_path)
            
        return True

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path = CHECKPOINT_DIR)

# %%
env = VizDoomGym() # non rendered-environment

agent = PPO('CnnPolicy', # policy type -> CnnPolicy since we are working on image frames
            env,
            tensorboard_log=LOG_DIR,
            verbose=1,
            learning_rate=0.00025,
            n_steps=2048)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
agent.learn(total_timesteps = 100000, callback=callback)
# Out:
# Logging to ./TC_logs/log_basic/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85       |
# |    ep_rew_mean     | 339      |
# | time/              |          |
# |    fps             | 230      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.2         |
# |    ep_rew_mean          | 344          |
# | time/                   |              |
# |    fps                  | 204          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0069572744 |
# |    clip_fraction        | 0.327        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | -0.000649    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 140          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.0153       |
# |    value_loss           | 331          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.1        |
# |    ep_rew_mean          | 335         |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 3           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012127946 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 243         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.0251      |
# |    value_loss           | 670         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.3        |
# |    ep_rew_mean          | 324         |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 4           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019986585 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0866      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 486         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.0105      |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.3        |
# |    ep_rew_mean          | 300         |
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 5           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.029694475 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 713         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0048      |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73          |
# |    ep_rew_mean          | 290         |
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 6           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013722936 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.622      |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 546         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0138      |
# |    value_loss           | 958         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.2        |
# |    ep_rew_mean          | 279         |
# | time/                   |             |
# |    fps                  | 184         |
# |    iterations           | 7           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018666241 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 336         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00549     |
# |    value_loss           | 957         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.5        |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 8           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.037446663 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 667         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00785     |
# |    value_loss           | 1.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.6        |
# |    ep_rew_mean          | 245         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 9           |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012258357 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 612         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0076      |
# |    value_loss           | 1.19e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.6        |
# |    ep_rew_mean          | 225         |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 10          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011931272 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 442         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0153      |
# |    value_loss           | 885         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53          |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 11          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.028335283 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 318         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.0163      |
# |    value_loss           | 675         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.9        |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 12          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.026860109 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.272      |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 224         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00995     |
# |    value_loss           | 508         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | 186          |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 13           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0040218187 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.22        |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 213          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.00183      |
# |    value_loss           | 410          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.6        |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 14          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014634111 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.253      |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 197         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0049      |
# |    value_loss           | 389         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.3         |
# |    ep_rew_mean          | 180          |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 15           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0026411382 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.161       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 176          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.00135      |
# |    value_loss           | 331          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.9       |
# |    ep_rew_mean          | 178        |
# | time/                   |            |
# |    fps                  | 192        |
# |    iterations           | 16         |
# |    time_elapsed         | 170        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.07720323 |
# |    clip_fraction        | 0.0275     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.101     |
# |    explained_variance   | 0.728      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 107        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.00395    |
# |    value_loss           | 426        |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 46.5          |
# |    ep_rew_mean          | 184           |
# | time/                   |               |
# |    fps                  | 189           |
# |    iterations           | 17            |
# |    time_elapsed         | 183           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00049728894 |
# |    clip_fraction        | 0.00166       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0132       |
# |    explained_variance   | 0.765         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 153           |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000118     |
# |    value_loss           | 332           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.5         |
# |    ep_rew_mean          | 180          |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 18           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0010506436 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0227      |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 123          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000227    |
# |    value_loss           | 358          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.6         |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 187          |
# |    iterations           | 19           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0012897225 |
# |    clip_fraction        | 0.00513      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.031       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 158          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 8.64e-05     |
# |    value_loss           | 384          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.7         |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 20           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0025286153 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0627      |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 145          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 346          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.5        |
# |    ep_rew_mean          | 184         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 21          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007842537 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0632     |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 162         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.000847    |
# |    value_loss           | 339         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.6        |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 22          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010472735 |
# |    clip_fraction        | 0.0225      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0758     |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 117         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00415     |
# |    value_loss           | 309         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.5        |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 23          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004519541 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0795     |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 204         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00105    |
# |    value_loss           | 398         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.8        |
# |    ep_rew_mean          | 190         |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 24          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005102304 |
# |    clip_fraction        | 0.0221      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.093      |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 229         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00161     |
# |    value_loss           | 354         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 48.9         |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 25           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0068289684 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.101       |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 153          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 419          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.3        |
# |    ep_rew_mean          | 180         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 26          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.007043216 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0785     |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 172         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 5.17e-07    |
# |    value_loss           | 406         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45          |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 27          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004959359 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0814     |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 150         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -7.63e-05   |
# |    value_loss           | 424         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 28          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008087484 |
# |    clip_fraction        | 0.0399      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.117      |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 157         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00313     |
# |    value_loss           | 337         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46         |
# |    ep_rew_mean          | 183        |
# | time/                   |            |
# |    fps                  | 190        |
# |    iterations           | 29         |
# |    time_elapsed         | 312        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.04870099 |
# |    clip_fraction        | 0.0615     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0852    |
# |    explained_variance   | 0.734      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 100        |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.00832    |
# |    value_loss           | 332        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.1        |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 30          |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006888016 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0776     |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 221         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 394         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 31          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.017924491 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 163         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0026      |
# |    value_loss           | 399         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.3        |
# |    ep_rew_mean          | 196         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 32          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.029159702 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.247      |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 174         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0178      |
# |    value_loss           | 557         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.1        |
# |    ep_rew_mean          | 191         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 33          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010774553 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 199         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00497     |
# |    value_loss           | 435         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | 194         |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 34          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014559026 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0886     |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 170         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00177     |
# |    value_loss           | 471         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.9        |
# |    ep_rew_mean          | 182         |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 35          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003666453 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.075      |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 196         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000884   |
# |    value_loss           | 476         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.7        |
# |    ep_rew_mean          | 169         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 36          |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004478368 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0693     |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 123         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 365         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.6       |
# |    ep_rew_mean          | 177        |
# | time/                   |            |
# |    fps                  | 188        |
# |    iterations           | 37         |
# |    time_elapsed         | 402        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.03439297 |
# |    clip_fraction        | 0.0455     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.126     |
# |    explained_variance   | 0.684      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 192        |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0009     |
# |    value_loss           | 372        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.8         |
# |    ep_rew_mean          | 182          |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 38           |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0047731176 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0933      |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 248          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00208      |
# |    value_loss           | 346          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.6        |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 39          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008840382 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.114      |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 327         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000108   |
# |    value_loss           | 388         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.1        |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 40          |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.002444698 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0673     |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 238         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.000588    |
# |    value_loss           | 426         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.5       |
# |    ep_rew_mean          | 180        |
# | time/                   |            |
# |    fps                  | 186        |
# |    iterations           | 41         |
# |    time_elapsed         | 449        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02961524 |
# |    clip_fraction        | 0.0343     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0843    |
# |    explained_variance   | 0.709      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 129        |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00577    |
# |    value_loss           | 339        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46          |
# |    ep_rew_mean          | 182         |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 42          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007492834 |
# |    clip_fraction        | 0.00981     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0621     |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 106         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 324         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.1       |
# |    ep_rew_mean          | 191        |
# | time/                   |            |
# |    fps                  | 186        |
# |    iterations           | 43         |
# |    time_elapsed         | 473        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01615897 |
# |    clip_fraction        | 0.0287     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.143     |
# |    explained_variance   | 0.772      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 99.2       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00339   |
# |    value_loss           | 283        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | 199         |
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 44          |
# |    time_elapsed         | 484         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012517567 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.164      |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 196         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00342     |
# |    value_loss           | 386         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.5       |
# |    ep_rew_mean          | 197        |
# | time/                   |            |
# |    fps                  | 185        |
# |    iterations           | 45         |
# |    time_elapsed         | 496        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02139679 |
# |    clip_fraction        | 0.0524     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.128     |
# |    explained_variance   | 0.725      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 147        |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00665    |
# |    value_loss           | 382        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.6        |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 46          |
# |    time_elapsed         | 507         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009612215 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 262         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00157     |
# |    value_loss           | 455         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.6        |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 47          |
# |    time_elapsed         | 517         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010785664 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0823     |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 96.5        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00693     |
# |    value_loss           | 338         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.8        |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 48          |
# |    time_elapsed         | 528         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.021722807 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.137      |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 241         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00801     |
# |    value_loss           | 585         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.9        |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 49          |
# |    time_elapsed         | 539         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.109111555 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.231      |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 434         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.02        |
# |    value_loss           | 804         |
# -----------------------------------------

# %% [markdown]
# # Testing and Evaluation

# %%
# Visual testing of the trained agent
agent = PPO.load('./TC_train/train_basic/best_model_100000.zip')
env = VizDoomGym(render_mode=True)

for episode in range(5):
    obs, info = env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = agent.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        time.sleep(0.02) # Slow down the rendering

    print("Episode: {}, Total Reward: {}".format(episode + 1, total_reward))
env.close()
# Out:
# *** Fatal Error ***
# Address not mapped to object (signal 11)
# Address: 0x7f35549a5f28
#
# Generating vizdoom-crash.log and killing process 13389, please wait... sh: 1: gdb: not found
# Warning: Missing charsets in String to FontSet conversion
